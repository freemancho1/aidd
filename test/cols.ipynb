# %%
cons = ['CONS_ID', 'TOTAL_CONS_COST', 'LAST_MOD_DATE', 'OFFICE_NAME', 'CONT_CAP', 'YEAR', 'MONTH', 'DAY', 'DAYOFWEEK', 'DAYOFYEAR', 'YEAR_MONTH', 'OFFICE_NUMBER']
cnts = ['CONS_ID', 'TOTAL_CONS_COST', 'LAST_MOD_DATE', 'OFFICE_NAME', 'CONT_CAP', 'YEAR', 'MONTH', 'DAY', 'DAYOFWEEK', 'DAYOFYEAR', 'YEAR_MONTH', 'OFFICE_NUMBER', 'POLE_CNT', 'LINE_CNT', 'SL_CNT']
pole = ['CONS_ID', 'TOTAL_CONS_COST', 'LAST_MOD_DATE', 'OFFICE_NAME', 'CONT_CAP', 'YEAR', 'MONTH', 'DAY', 'DAYOFWEEK', 'DAYOFYEAR', 'YEAR_MONTH', 'OFFICE_NUMBER', 'POLE_CNT', 'LINE_CNT', 'SL_CNT', 'POLE_SHAPE_G', 'POLE_SHAPE_O', 'POLE_SHAPE_V', 'POLE_TYPE_0', 'POLE_TYPE_1', 'POLE_TYPE_B', 'POLE_TYPE_C', 'POLE_TYPE_E', 'POLE_TYPE_H', 'POLE_TYPE_M', 'POLE_TYPE_R', 'POLE_SPEC_0.0', 'POLE_SPEC_6.0', 'POLE_SPEC_8.0', 'POLE_SPEC_10.0', 'POLE_SPEC_11.0', 'POLE_SPEC_12.0', 'POLE_SPEC_14.0', 'POLE_SPEC_16.0']
line = ['CONS_ID', 'TOTAL_CONS_COST', 'LAST_MOD_DATE', 'OFFICE_NAME', 'CONT_CAP', 'YEAR', 'MONTH', 'DAY', 'DAYOFWEEK', 'DAYOFYEAR', 'YEAR_MONTH', 'OFFICE_NUMBER', 'POLE_CNT', 'LINE_CNT', 'SL_CNT', 'POLE_SHAPE_G', 'POLE_SHAPE_O', 'POLE_SHAPE_V', 'POLE_TYPE_0', 'POLE_TYPE_1', 'POLE_TYPE_B', 'POLE_TYPE_C', 'POLE_TYPE_E', 'POLE_TYPE_H', 'POLE_TYPE_M', 'POLE_TYPE_R', 'POLE_SPEC_0.0', 'POLE_SPEC_6.0', 'POLE_SPEC_8.0', 'POLE_SPEC_10.0', 'POLE_SPEC_11.0', 'POLE_SPEC_12.0', 'POLE_SPEC_14.0', 'POLE_SPEC_16.0', 'SPAN', 'LINE_LENGTH', 'WIRING_SCHEME_AO', 'WIRING_SCHEME_C1', 'WIRING_SCHEME_C2', 'WIRING_SCHEME_C4', 'WIRING_SCHEME_D2', 'WIRING_SCHEME_D4', 'WIRING_SCHEME_EW', 'WIRING_SCHEME_OC', 'WIRING_SCHEME_OW', 'LINE_TYPE_3.2', 'LINE_TYPE_22.0', 'LINE_TYPE_25.0', 'LINE_TYPE_32.0', 'LINE_TYPE_35.0', 'LINE_TYPE_38.0', 'LINE_TYPE_58.0', 'LINE_TYPE_60.0', 'LINE_TYPE_70.0', 'LINE_TYPE_100.0', 'LINE_SPEC_1', 'LINE_SPEC_2', 'LINE_SPEC_3', 'LINE_PHASE_AL', 'LINE_PHASE_AO', 'LINE_PHASE_C1', 'LINE_PHASE_NaN', 'LINE_PHASE_OC', 'LINE_PHASE_OW', 'LINE_PHASE_WO', 'LINE_PHASE_ZZ', 'NEUTRAL_TYPE_0.0', 'NEUTRAL_TYPE_22.0', 'NEUTRAL_TYPE_32.0', 'NEUTRAL_TYPE_35.0', 'NEUTRAL_TYPE_38.0', 'NEUTRAL_TYPE_58.0', 'NEUTRAL_TYPE_60.0', 'NEUTRAL_TYPE_95.0', 'NEUTRAL_TYPE_100.0', 'NEUTRAL_TYPE_999.0', 'NEUTRAL_SPEC_13', 'NEUTRAL_SPEC_43']
sl = ['CONS_ID', 'TOTAL_CONS_COST', 'LAST_MOD_DATE', 'OFFICE_NAME', 'CONT_CAP', 'YEAR', 'MONTH', 'DAY', 'DAYOFWEEK', 'DAYOFYEAR', 'YEAR_MONTH', 'OFFICE_NUMBER', 'POLE_CNT', 'LINE_CNT', 'SL_CNT', 'POLE_SHAPE_G', 'POLE_SHAPE_O', 'POLE_SHAPE_V', 'POLE_TYPE_0', 'POLE_TYPE_1', 'POLE_TYPE_B', 'POLE_TYPE_C', 'POLE_TYPE_E', 'POLE_TYPE_H', 'POLE_TYPE_M', 'POLE_TYPE_R', 'POLE_SPEC_0.0', 'POLE_SPEC_6.0', 'POLE_SPEC_8.0', 'POLE_SPEC_10.0', 'POLE_SPEC_11.0', 'POLE_SPEC_12.0', 'POLE_SPEC_14.0', 'POLE_SPEC_16.0', 'SPAN', 'LINE_LENGTH', 'WIRING_SCHEME_AO', 'WIRING_SCHEME_C1', 'WIRING_SCHEME_C2', 'WIRING_SCHEME_C4', 'WIRING_SCHEME_D2', 'WIRING_SCHEME_D4', 'WIRING_SCHEME_EW', 'WIRING_SCHEME_OC', 'WIRING_SCHEME_OW', 'LINE_TYPE_3.2', 'LINE_TYPE_22.0', 'LINE_TYPE_25.0', 'LINE_TYPE_32.0', 'LINE_TYPE_35.0', 'LINE_TYPE_38.0', 'LINE_TYPE_58.0', 'LINE_TYPE_60.0', 'LINE_TYPE_70.0', 'LINE_TYPE_100.0', 'LINE_SPEC_1', 'LINE_SPEC_2', 'LINE_SPEC_3', 'LINE_PHASE_AL', 'LINE_PHASE_AO', 'LINE_PHASE_C1', 'LINE_PHASE_NaN', 'LINE_PHASE_OC', 'LINE_PHASE_OW', 'LINE_PHASE_WO', 'LINE_PHASE_ZZ', 'NEUTRAL_TYPE_0.0', 'NEUTRAL_TYPE_22.0', 'NEUTRAL_TYPE_32.0', 'NEUTRAL_TYPE_35.0', 'NEUTRAL_TYPE_38.0', 'NEUTRAL_TYPE_58.0', 'NEUTRAL_TYPE_60.0', 'NEUTRAL_TYPE_95.0', 'NEUTRAL_TYPE_100.0', 'NEUTRAL_TYPE_999.0', 'NEUTRAL_SPEC_13', 'NEUTRAL_SPEC_43', 'REAL_SL_CNT', 'SL_SPAN_SUM', 'SUPERVISOR', 'SL_TYPE_C1', 'SL_TYPE_C2', 'SL_TYPE_C4', 'SL_TYPE_D2', 'SL_TYPE_D3', 'SL_TYPE_D4', 'SL_TYPE_OW', 'SL_TYPE_V2', 'SL_TYPE_ZZ', 'SL_SPEC_0.0', 'SL_SPEC_1.6', 'SL_SPEC_2.6', 'SL_SPEC_3.2', 'SL_SPEC_5.5', 'SL_SPEC_10.0', 'SL_SPEC_14.0', 'SL_SPEC_16.0', 'SL_SPEC_22.0', 'SL_SPEC_25.0', 'SL_SPEC_35.0', 'SL_SPEC_38.0', 'SL_SPEC_60.0', 'SL_SPEC_70.0', 'SL_SPEC_100.0', 'SL_SPEC_120.0', 'SL_SPEC_240.0']
last = ['CONS_ID', 'TOTAL_CONS_COST', 'LAST_MOD_DATE', 'OFFICE_NAME', 'CONT_CAP', 'YEAR', 'MONTH', 'DAY', 'DAYOFWEEK', 'DAYOFYEAR', 'YEAR_MONTH', 'OFFICE_NUMBER', 'POLE_CNT', 'LINE_CNT', 'SL_CNT', 'POLE_SHAPE_G', 'POLE_SHAPE_O', 'POLE_SHAPE_V', 'POLE_TYPE_0', 'POLE_TYPE_1', 'POLE_TYPE_B', 'POLE_TYPE_C', 'POLE_TYPE_E', 'POLE_TYPE_H', 'POLE_TYPE_M', 'POLE_TYPE_R', 'POLE_SPEC_0.0', 'POLE_SPEC_6.0', 'POLE_SPEC_8.0', 'POLE_SPEC_10.0', 'POLE_SPEC_11.0', 'POLE_SPEC_12.0', 'POLE_SPEC_14.0', 'POLE_SPEC_16.0', 'SPAN', 'LINE_LENGTH', 'WIRING_SCHEME_AO', 'WIRING_SCHEME_C1', 'WIRING_SCHEME_C2', 'WIRING_SCHEME_C4', 'WIRING_SCHEME_D2', 'WIRING_SCHEME_D4', 'WIRING_SCHEME_EW', 'WIRING_SCHEME_OC', 'WIRING_SCHEME_OW', 'LINE_TYPE_3.2', 'LINE_TYPE_22.0', 'LINE_TYPE_25.0', 'LINE_TYPE_32.0', 'LINE_TYPE_35.0', 'LINE_TYPE_38.0', 'LINE_TYPE_58.0', 'LINE_TYPE_60.0', 'LINE_TYPE_70.0', 'LINE_TYPE_100.0', 'LINE_SPEC_1', 'LINE_SPEC_2', 'LINE_SPEC_3', 'LINE_PHASE_AL', 'LINE_PHASE_AO', 'LINE_PHASE_C1', 'LINE_PHASE_NaN', 'LINE_PHASE_OC', 'LINE_PHASE_OW', 'LINE_PHASE_WO', 'LINE_PHASE_ZZ', 'NEUTRAL_TYPE_0.0', 'NEUTRAL_TYPE_22.0', 'NEUTRAL_TYPE_32.0', 'NEUTRAL_TYPE_35.0', 'NEUTRAL_TYPE_38.0', 'NEUTRAL_TYPE_58.0', 'NEUTRAL_TYPE_60.0', 'NEUTRAL_TYPE_95.0', 'NEUTRAL_TYPE_100.0', 'NEUTRAL_TYPE_999.0', 'NEUTRAL_SPEC_13', 'NEUTRAL_SPEC_43', 'REAL_SL_CNT', 'SL_SPAN_SUM', 'SUPERVISOR', 'SL_TYPE_C1', 'SL_TYPE_C2', 'SL_TYPE_C4', 'SL_TYPE_D2', 'SL_TYPE_D3', 'SL_TYPE_D4', 'SL_TYPE_OW', 'SL_TYPE_V2', 'SL_TYPE_ZZ', 'SL_SPEC_0.0', 'SL_SPEC_1.6', 'SL_SPEC_2.6', 'SL_SPEC_3.2', 'SL_SPEC_5.5', 'SL_SPEC_10.0', 'SL_SPEC_14.0', 'SL_SPEC_16.0', 'SL_SPEC_22.0', 'SL_SPEC_25.0', 'SL_SPEC_35.0', 'SL_SPEC_38.0', 'SL_SPEC_60.0', 'SL_SPEC_70.0', 'SL_SPEC_100.0', 'SL_SPEC_120.0', 'SL_SPEC_240.0']
